# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('churn.csv')

# %%
df.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# 1              Yes          No          No              No        One year
# 2               No          No          No              No  Month-to-month
# 3              Yes         Yes          No              No        One year
# 4               No          No          No              No  Month-to-month
#
#   PaperlessBilling              PaymentMethod  MonthlyCharges  TotalCharges  \
# 0              Yes           Electronic check           29.85         29.85
# 1               No               Mailed check           56.95       1889.50
# 2              Yes               Mailed check           53.85        108.15
# 3               No  Bank transfer (automatic)           42.30       1840.75
# 4              Yes           Electronic check           70.70        151.65
#
#   Churn
# 0    No
# 1    No
# 2   Yes
# 3    No
# 4   Yes

# %%
X=df.drop(['Churn'], axis=1)

# %%
X.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# 1              Yes          No          No              No        One year
# 2               No          No          No              No  Month-to-month
# 3              Yes         Yes          No              No        One year
# 4               No          No          No              No  Month-to-month
#
#   PaperlessBilling              PaymentMethod  MonthlyCharges  TotalCharges
# 0              Yes           Electronic check           29.85         29.85
# 1               No               Mailed check           56.95       1889.50
# 2              Yes               Mailed check           53.85        108.15
# 3               No  Bank transfer (automatic)           42.30       1840.75
# 4              Yes           Electronic check           70.70        151.65

# %%
y=pd.DataFrame()
y['Churn']=df['Churn']

# %%
y.head()
# Out:
#   Churn
# 0    No
# 1    No
# 2   Yes
# 3    No
# 4   Yes

# %%
nominal_category=['gender','Partner','Dependents','PaymentMethod']
ordinal_category=['PhoneService','MultipleLines','InternetService','OnlineSecurity','OnlineBackup',
                 'DeviceProtection','TechSupport','StreamingTV','StreamingMovies','Contract','PaperlessBilling']

# %%
X.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# 1              Yes          No          No              No        One year
# 2               No          No          No              No  Month-to-month
# 3              Yes         Yes          No              No        One year
# 4               No          No          No              No  Month-to-month
#
#   PaperlessBilling              PaymentMethod  MonthlyCharges  TotalCharges
# 0              Yes           Electronic check           29.85         29.85
# 1               No               Mailed check           56.95       1889.50
# 2              Yes               Mailed check           53.85        108.15
# 3               No  Bank transfer (automatic)           42.30       1840.75
# 4              Yes           Electronic check           70.70        151.65

# %%
df['gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df['Partner'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df['Dependents'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df['PaymentMethod'].unique()
# Out:
# array(['Electronic check', 'Mailed check', 'Bank transfer (automatic)',
#        'Credit card (automatic)'], dtype=object)

# %%
X1=pd.get_dummies(X['gender'],drop_first=True)

# %%
X
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female              0     Yes         No       1           No
# 1       Male              0      No         No      34          Yes
# 2       Male              0      No         No       2          Yes
# 3       Male              0      No         No      45           No
# 4     Female              0      No         No       2          Yes
# ...      ...            ...     ...        ...     ...          ...
# 7038    Male              0     Yes        Yes      24          Yes
# 7039  Female              0     Yes        Yes      72          Yes
# 7040  Female              0     Yes        Yes      11           No
# 7041    Male              1     Yes         No       4          Yes
# 7042    Male              0      No         No      66          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0     No phone service             DSL             No          Yes
# 1                   No             DSL            Yes           No
# 2                   No             DSL            Yes          Yes
# 3     No phone service             DSL            Yes           No
# 4                   No     Fiber optic             No           No
# ...                ...             ...            ...          ...
# 7038               Yes             DSL            Yes           No
# 7039               Yes     Fiber optic             No          Yes
# 7040  No phone service             DSL            Yes           No
# 7041               Yes     Fiber optic             No           No
# 7042                No     Fiber optic            Yes           No
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0                  No          No          No              No  Month-to-month
# 1                 Yes          No          No              No        One year
# 2                  No          No          No              No  Month-to-month
# 3                 Yes         Yes          No              No        One year
# 4                  No          No          No              No  Month-to-month
# ...               ...         ...         ...             ...             ...
# 7038              Yes         Yes         Yes             Yes        One year
# 7039              Yes          No         Yes             Yes        One year
# 7040               No          No          No              No  Month-to-month
# 7041               No          No          No              No  Month-to-month
# 7042              Yes         Yes         Yes             Yes        Two year
#
#      PaperlessBilling              PaymentMethod  MonthlyCharges  TotalCharges
# 0                 Yes           Electronic check           29.85         29.85
# 1                  No               Mailed check           56.95       1889.50
# 2                 Yes               Mailed check           53.85        108.15
# 3                  No  Bank transfer (automatic)           42.30       1840.75
# 4                 Yes           Electronic check           70.70        151.65
# ...               ...                        ...             ...           ...
# 7038              Yes               Mailed check           84.80       1990.50
# 7039              Yes    Credit card (automatic)          103.20       7362.90
# 7040              Yes           Electronic check           29.60        346.45
# 7041              Yes               Mailed check           74.40        306.60
# 7042              Yes  Bank transfer (automatic)          105.65       6844.50
#
# [7043 rows x 19 columns]

# %%
X1.head()
# Out:
#    Male
# 0     0
# 1     1
# 2     1
# 3     1
# 4     0

# %%
for i in nominal_category:
    
    X = pd.concat([X, pd.get_dummies(X[i],drop_first=True,prefix=i)], axis=1)

# %%
X=X.drop(['gender','Partner','Dependents','PaymentMethod'], axis=1)

# %%
X.head()
# Out:
#    SeniorCitizen  tenure PhoneService     MultipleLines InternetService  \
# 0              0       1           No  No phone service             DSL
# 1              0      34          Yes                No             DSL
# 2              0       2          Yes                No             DSL
# 3              0      45           No  No phone service             DSL
# 4              0       2          Yes                No     Fiber optic
#
#   OnlineSecurity OnlineBackup DeviceProtection TechSupport StreamingTV  ...  \
# 0             No          Yes               No          No          No  ...
# 1            Yes           No              Yes          No          No  ...
# 2            Yes          Yes               No          No          No  ...
# 3            Yes           No              Yes         Yes          No  ...
# 4             No           No               No          No          No  ...
#
#          Contract PaperlessBilling MonthlyCharges  TotalCharges  gender_Male  \
# 0  Month-to-month              Yes          29.85         29.85            0
# 1        One year               No          56.95       1889.50            1
# 2  Month-to-month              Yes          53.85        108.15            1
# 3        One year               No          42.30       1840.75            1
# 4  Month-to-month              Yes          70.70        151.65            0
#
#    Partner_Yes  Dependents_Yes  PaymentMethod_Credit card (automatic)  \
# 0            1               0                                      0
# 1            0               0                                      0
# 2            0               0                                      0
# 3            0               0                                      0
# 4            0               0                                      0
#
#    PaymentMethod_Electronic check  PaymentMethod_Mailed check
# 0                               1                           0
# 1                               0                           1
# 2                               0                           1
# 3                               0                           0
# 4                               1                           0
#
# [5 rows x 21 columns]

# %%
ordinal_category=['SeniorCitizen','PhoneService','MultipleLines','InternetService','OnlineSecurity','OnlineBackup',
                 'DeviceProtection','TechSupport','StreamingTV','StreamingMovies','Contract','PaperlessBilling']

# %%
df['PhoneService'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
import category_encoders as ce
import pandas as pd

# create object of Ordinalencoding
encoder= ce.OrdinalEncoder(cols=['PhoneService'],return_df=True,
                           mapping=[{'col':'PhoneService',
'mapping':{'No':0,'Yes':1}}])

X['PhoneService'] = encoder.fit_transform(X['PhoneService'])
#Original data

# %%
df['MultipleLines'].unique()
# Out:
# array(['No phone service', 'No', 'Yes'], dtype=object)

# %%
e1= ce.OrdinalEncoder(cols=['MultipleLines'],return_df=True,
                           mapping=[{'col':'MultipleLines',
'mapping':{'No phone service':0,'No':1,'Yes':2}}])

X['MultipleLines'] = e1.fit_transform(X['MultipleLines'])

# %%
df['InternetService'].unique()
# Out:
# array(['DSL', 'Fiber optic', 'No'], dtype=object)

# %%
e2= ce.OrdinalEncoder(cols=['InternetService'],return_df=True,
                           mapping=[{'col':'InternetService',
'mapping':{'No':0,'Fiber optic':1,'DSL':2}}])

X['InternetService'] = e2.fit_transform(X['InternetService'])

# %%
df['OnlineSecurity'].unique()
# Out:
# array(['No', 'Yes', 'No internet service'], dtype=object)

# %%
e3= ce.OrdinalEncoder(cols=['OnlineSecurity'],return_df=True,
                           mapping=[{'col':'OnlineSecurity',
'mapping':{'No internet service':0,'No':1,'Yes':2}}])

X['OnlineSecurity'] = e3.fit_transform(X['OnlineSecurity'])

# %%
df['OnlineBackup'].unique()
# Out:
# array(['Yes', 'No', 'No internet service'], dtype=object)

# %%
e4= ce.OrdinalEncoder(cols=['OnlineBackup'],return_df=True,
                           mapping=[{'col':'OnlineBackup',
'mapping':{'No internet service':0,'No':1,'Yes':2}}])

X['OnlineBackup'] = e4.fit_transform(X['OnlineBackup'])

# %%
df['DeviceProtection'].unique()
# Out:
# array(['No', 'Yes', 'No internet service'], dtype=object)

# %%
e6= ce.OrdinalEncoder(cols=['DeviceProtection'],return_df=True,
                           mapping=[{'col':'DeviceProtection',
'mapping':{'No internet service':0,'No':1,'Yes':2}}])

X['DeviceProtection'] = e6.fit_transform(X['DeviceProtection'])

# %%
df['TechSupport'].unique()
# Out:
# array(['No', 'Yes', 'No internet service'], dtype=object)

# %%
e7= ce.OrdinalEncoder(cols=['TechSupport'],return_df=True,
                           mapping=[{'col':'TechSupport',
'mapping':{'No internet service':0,'No':1,'Yes':2}}])

X['TechSupport'] = e7.fit_transform(X['TechSupport'])

# %%
df['StreamingTV'].unique()
# Out:
# array(['No', 'Yes', 'No internet service'], dtype=object)

# %%
e8= ce.OrdinalEncoder(cols=['StreamingTV'],return_df=True,
                           mapping=[{'col':'StreamingTV',
'mapping':{'No internet service':0,'No':1,'Yes':2}}])

X['StreamingTV'] = e8.fit_transform(X['StreamingTV'])

# %%
df['StreamingMovies'].unique()
# Out:
# array(['No', 'Yes', 'No internet service'], dtype=object)

# %%
e9= ce.OrdinalEncoder(cols=['StreamingMovies'],return_df=True,
                           mapping=[{'col':'StreamingMovies',
'mapping':{'No internet service':0,'No':1,'Yes':2}}])

X['StreamingMovies'] = e9.fit_transform(X['StreamingMovies'])

# %%
df['Contract'].unique()
# Out:
# array(['Month-to-month', 'One year', 'Two year'], dtype=object)

# %%
e10= ce.OrdinalEncoder(cols=['Contract'],return_df=True,
                           mapping=[{'col':'Contract',
'mapping':{'Month-to-month':0,'One year':1,'Two year':2}}])

X['Contract'] = e10.fit_transform(X['Contract'])

# %%
df['PaperlessBilling'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
e12= ce.OrdinalEncoder(cols=['PaperlessBilling'],return_df=True,
                           mapping=[{'col':'PaperlessBilling',
'mapping':{'No':0,'Yes':1}}])

X['PaperlessBilling'] = e12.fit_transform(X['PaperlessBilling'])

# %%
X.head()
# Out:
#    SeniorCitizen  tenure  PhoneService  MultipleLines  InternetService  \
# 0              0       1             0              0                2
# 1              0      34             1              1                2
# 2              0       2             1              1                2
# 3              0      45             0              0                2
# 4              0       2             1              1                1
#
#    OnlineSecurity  OnlineBackup  DeviceProtection  TechSupport  StreamingTV  \
# 0               1             2                 1            1            1
# 1               2             1                 2            1            1
# 2               2             2                 1            1            1
# 3               2             1                 2            2            1
# 4               1             1                 1            1            1
#
#    ...  Contract  PaperlessBilling  MonthlyCharges  TotalCharges  gender_Male  \
# 0  ...         0                 1           29.85         29.85            0
# 1  ...         1                 0           56.95       1889.50            1
# 2  ...         0                 1           53.85        108.15            1
# 3  ...         1                 0           42.30       1840.75            1
# 4  ...         0                 1           70.70        151.65            0
#
#    Partner_Yes  Dependents_Yes  PaymentMethod_Credit card (automatic)  \
# 0            1               0                                      0
# 1            0               0                                      0
# 2            0               0                                      0
# 3            0               0                                      0
# 4            0               0                                      0
#
#    PaymentMethod_Electronic check  PaymentMethod_Mailed check
# 0                               1                           0
# 1                               0                           1
# 2                               0                           1
# 3                               0                           0
# 4                               1                           0
#
# [5 rows x 21 columns]

# %%
X.corr()
# Out:
#                                        SeniorCitizen    tenure  PhoneService  \
# SeniorCitizen                               1.000000  0.016567      0.008576
# tenure                                      0.016567  1.000000      0.008448
# PhoneService                                0.008576  0.008448      1.000000
# MultipleLines                               0.113791  0.258958      0.675070
# InternetService                             0.032310  0.030359     -0.387436
# OnlineSecurity                              0.081878  0.232373     -0.159989
# OnlineBackup                                0.144828  0.253743     -0.129770
# DeviceProtection                            0.140298  0.253999     -0.142012
# TechSupport                                 0.067457  0.230522     -0.161930
# StreamingTV                                 0.167188  0.201053     -0.108239
# StreamingMovies                             0.176469  0.205031     -0.114715
# Contract                                   -0.142554  0.671607      0.002247
# PaperlessBilling                            0.156530  0.006152      0.016505
# MonthlyCharges                              0.220173  0.247900      0.247398
# TotalCharges                                0.102652  0.825464      0.113013
# gender_Male                                -0.001874  0.005106     -0.006488
# Partner_Yes                                 0.016479  0.379697      0.017706
# Dependents_Yes                             -0.211185  0.159712     -0.001762
# PaymentMethod_Credit card (automatic)      -0.024135  0.233006     -0.007721
# PaymentMethod_Electronic check              0.171718 -0.208363      0.003062
# PaymentMethod_Mailed check                 -0.153477 -0.233852     -0.003319
#
#                                        MultipleLines  InternetService  \
# SeniorCitizen                               0.113791         0.032310
# tenure                                      0.258958         0.030359
# PhoneService                                0.675070        -0.387436
# MultipleLines                               1.000000        -0.186826
# InternetService                            -0.186826         1.000000
# OnlineSecurity                              0.069085         0.720587
# OnlineBackup                                0.130619         0.650962
# DeviceProtection                            0.124502         0.646159
# TechSupport                                 0.069149         0.716993
# StreamingTV                                 0.165254         0.593193
# StreamingMovies                             0.162841         0.597266
# Contract                                    0.083343        -0.099721
# PaperlessBilling                            0.133255         0.138625
# MonthlyCharges                              0.490700         0.323260
# TotalCharges                                0.412166         0.175589
# gender_Male                                -0.009451         0.000863
# Partner_Yes                                 0.117307        -0.000891
# Dependents_Yes                             -0.019657        -0.044590
# PaymentMethod_Credit card (automatic)       0.042590         0.032540
# PaymentMethod_Electronic check              0.065663         0.091881
# PaymentMethod_Mailed check                 -0.176117        -0.152481
#
#                                        OnlineSecurity  OnlineBackup  \
# SeniorCitizen                                0.081878      0.144828
# tenure                                       0.232373      0.253743
# PhoneService                                -0.159989     -0.129770
# MultipleLines                                0.069085      0.130619
# InternetService                              0.720587      0.650962
# OnlineSecurity                               1.000000      0.705166
# OnlineBackup                                 0.705166      1.000000
# DeviceProtection                             0.701690      0.711335
# TechSupport                                  0.735191      0.709216
# StreamingTV                                  0.662220      0.703167
# StreamingMovies                              0.667033      0.700158
# Contract                                     0.015824     -0.035407
# PaperlessBilling                             0.184993      0.260715
# MonthlyCharges                               0.635534      0.710477
# TotalCharges                                 0.482605      0.537169
# gender_Male                                 -0.014418     -0.012230
# Partner_Yes                                  0.091303      0.090753
# Dependents_Yes                              -0.029721     -0.062775
# PaymentMethod_Credit card (automatic)        0.073520      0.057873
# PaymentMethod_Electronic check               0.094304      0.158719
# PaymentMethod_Mailed check                  -0.239277     -0.291444
#
#                                        DeviceProtection  TechSupport  \
# SeniorCitizen                                  0.140298     0.067457
# tenure                                         0.253999     0.230522
# PhoneService                                  -0.142012    -0.161930
# MultipleLines                                  0.124502     0.069149
# InternetService                                0.646159     0.716993
# OnlineSecurity                                 0.701690     0.735191
# OnlineBackup                                   0.711335     0.709216
# DeviceProtection                               1.000000     0.725327
# TechSupport                                    0.725327     1.000000
# StreamingTV                                    0.748182     0.703866
# StreamingMovies                                0.752952     0.704587
# Contract                                       0.005848     0.047218
# PaperlessBilling                               0.246069     0.211031
# MonthlyCharges                                 0.737104     0.661032
# TotalCharges                                   0.545529     0.495075
# gender_Male                                   -0.004720    -0.009409
# Partner_Yes                                    0.098664     0.076551
# Dependents_Yes                                -0.069078    -0.040788
# PaymentMethod_Credit card (automatic)          0.071243     0.074562
# PaymentMethod_Electronic check                 0.156932     0.092152
# PaymentMethod_Mailed check                    -0.300069    -0.241759
#
#                                        StreamingTV  ...  Contract  \
# SeniorCitizen                             0.167188  ... -0.142554
# tenure                                    0.201053  ...  0.671607
# PhoneService                             -0.108239  ...  0.002247
# MultipleLines                             0.165254  ...  0.083343
# InternetService                           0.593193  ... -0.099721
# OnlineSecurity                            0.662220  ...  0.015824
# OnlineBackup                              0.703167  ... -0.035407
# DeviceProtection                          0.748182  ...  0.005848
# TechSupport                               0.703866  ...  0.047218
# StreamingTV                               1.000000  ... -0.065128
# StreamingMovies                           0.807221  ... -0.062583
# Contract                                 -0.065128  ...  1.000000
# PaperlessBilling                          0.318581  ... -0.176733
# MonthlyCharges                            0.820225  ... -0.074195
# TotalCharges                              0.535105  ...  0.448564
# gender_Male                              -0.008673  ...  0.000126
# Partner_Yes                               0.079785  ...  0.294806
# Dependents_Yes                           -0.086739  ...  0.243187
# PaymentMethod_Credit card (automatic)     0.025425  ...  0.210659
# PaymentMethod_Electronic check            0.248025  ... -0.342575
# PaymentMethod_Mailed check               -0.334131  ... -0.004882
#
#                                        PaperlessBilling  MonthlyCharges  \
# SeniorCitizen                                  0.156530        0.220173
# tenure                                         0.006152        0.247900
# PhoneService                                   0.016505        0.247398
# MultipleLines                                  0.133255        0.490700
# InternetService                                0.138625        0.323260
# OnlineSecurity                                 0.184993        0.635534
# OnlineBackup                                   0.260715        0.710477
# DeviceProtection                               0.246069        0.737104
# TechSupport                                    0.211031        0.661032
# StreamingTV                                    0.318581        0.820225
# StreamingMovies                                0.310385        0.817842
# Contract                                      -0.176733       -0.074195
# PaperlessBilling                               1.000000        0.352150
# MonthlyCharges                                 0.352150        1.000000
# TotalCharges                                   0.158055        0.650865
# gender_Male                                   -0.011754       -0.014569
# Partner_Yes                                   -0.014877        0.096848
# Dependents_Yes                                -0.111377       -0.113890
# PaymentMethod_Credit card (automatic)         -0.013589        0.030550
# PaymentMethod_Electronic check                 0.208865        0.271625
# PaymentMethod_Mailed check                    -0.205398       -0.377437
#
#                                        TotalCharges  gender_Male  Partner_Yes  \
# SeniorCitizen                              0.102652    -0.001874     0.016479
# tenure                                     0.825464     0.005106     0.379697
# PhoneService                               0.113013    -0.006488     0.017706
# MultipleLines                              0.412166    -0.009451     0.117307
# InternetService                            0.175589     0.000863    -0.000891
# OnlineSecurity                             0.482605    -0.014418     0.091303
# OnlineBackup                               0.537169    -0.012230     0.090753
# DeviceProtection                           0.545529    -0.004720     0.098664
# TechSupport                                0.495075    -0.009409     0.076551
# StreamingTV                                0.535105    -0.008673     0.079785
# StreamingMovies                            0.537535    -0.010011     0.075098
# Contract                                   0.448564     0.000126     0.294806
# PaperlessBilling                           0.158055    -0.011754    -0.014877
# MonthlyCharges                             0.650865    -0.014569     0.096848
# TotalCharges                               1.000000    -0.000002     0.318364
# gender_Male                               -0.000002     1.000000    -0.001808
# Partner_Yes                                0.318364    -0.001808     1.000000
# Dependents_Yes                             0.063593     0.010517     0.452676
# PaymentMethod_Credit card (automatic)      0.182745     0.001215     0.082029
# PaymentMethod_Electronic check            -0.059971     0.000752    -0.083852
# PaymentMethod_Mailed check                -0.294815     0.013744    -0.095125
#
#                                        Dependents_Yes  \
# SeniorCitizen                               -0.211185
# tenure                                       0.159712
# PhoneService                                -0.001762
# MultipleLines                               -0.019657
# InternetService                             -0.044590
# OnlineSecurity                              -0.029721
# OnlineBackup                                -0.062775
# DeviceProtection                            -0.069078
# TechSupport                                 -0.040788
# StreamingTV                                 -0.086739
# StreamingMovies                             -0.101475
# Contract                                     0.243187
# PaperlessBilling                            -0.111377
# MonthlyCharges                              -0.113890
# TotalCharges                                 0.063593
# gender_Male                                  0.010517
# Partner_Yes                                  0.452676
# Dependents_Yes                               1.000000
# PaymentMethod_Credit card (automatic)        0.060267
# PaymentMethod_Electronic check              -0.150642
# PaymentMethod_Mailed check                   0.059071
#
#                                        PaymentMethod_Credit card (automatic)  \
# SeniorCitizen                                                      -0.024135
# tenure                                                              0.233006
# PhoneService                                                       -0.007721
# MultipleLines                                                       0.042590
# InternetService                                                     0.032540
# OnlineSecurity                                                      0.073520
# OnlineBackup                                                        0.057873
# DeviceProtection                                                    0.071243
# TechSupport                                                         0.074562
# StreamingTV                                                         0.025425
# StreamingMovies                                                     0.030648
# Contract                                                            0.210659
# PaperlessBilling                                                   -0.013589
# MonthlyCharges                                                      0.030550
# TotalCharges                                                        0.182745
# gender_Male                                                         0.001215
# Partner_Yes                                                         0.082029
# Dependents_Yes                                                      0.060267
# PaymentMethod_Credit card (automatic)                               1.000000
# PaymentMethod_Electronic check                                     -0.373322
# PaymentMethod_Mailed check                                         -0.286049
#
#                                        PaymentMethod_Electronic check  \
# SeniorCitizen                                                0.171718
# tenure                                                      -0.208363
# PhoneService                                                 0.003062
# MultipleLines                                                0.065663
# InternetService                                              0.091881
# OnlineSecurity                                               0.094304
# OnlineBackup                                                 0.158719
# DeviceProtection                                             0.156932
# TechSupport                                                  0.092152
# StreamingTV                                                  0.248025
# StreamingMovies                                              0.243398
# Contract                                                    -0.342575
# PaperlessBilling                                             0.208865
# MonthlyCharges                                               0.271625
# TotalCharges                                                -0.059971
# gender_Male                                                  0.000752
# Partner_Yes                                                 -0.083852
# Dependents_Yes                                              -0.150642
# PaymentMethod_Credit card (automatic)                       -0.373322
# PaymentMethod_Electronic check                               1.000000
# PaymentMethod_Mailed check                                  -0.387372
#
#                                        PaymentMethod_Mailed check
# SeniorCitizen                                           -0.153477
# tenure                                                  -0.233852
# PhoneService                                            -0.003319
# MultipleLines                                           -0.176117
# InternetService                                         -0.152481
# OnlineSecurity                                          -0.239277
# OnlineBackup                                            -0.291444
# DeviceProtection                                        -0.300069
# TechSupport                                             -0.241759
# StreamingTV                                             -0.334131
# StreamingMovies                                         -0.335553
# Contract                                                -0.004882
# PaperlessBilling                                        -0.205398
# MonthlyCharges                                          -0.377437
# TotalCharges                                            -0.294815
# gender_Male                                              0.013744
# Partner_Yes                                             -0.095125
# Dependents_Yes                                           0.059071
# PaymentMethod_Credit card (automatic)                   -0.286049
# PaymentMethod_Electronic check                          -0.387372
# PaymentMethod_Mailed check                               1.000000
#
# [21 rows x 21 columns]

# %%
e13= ce.OrdinalEncoder(cols=['Churn'],return_df=True,
                           mapping=[{'col':'Churn',
'mapping':{'No':0,'Yes':1}}])

y['Churn'] = e13.fit_transform(y['Churn'])

# %%
y.head()
# Out:
#    Churn
# 0      0
# 1      0
# 2      1
# 3      0
# 4      1

# %%
X.corr()
# Out:
#                                        SeniorCitizen    tenure  PhoneService  \
# SeniorCitizen                               1.000000  0.016567      0.008576
# tenure                                      0.016567  1.000000      0.008448
# PhoneService                                0.008576  0.008448      1.000000
# MultipleLines                               0.113791  0.258958      0.675070
# InternetService                             0.032310  0.030359     -0.387436
# OnlineSecurity                              0.081878  0.232373     -0.159989
# OnlineBackup                                0.144828  0.253743     -0.129770
# DeviceProtection                            0.140298  0.253999     -0.142012
# TechSupport                                 0.067457  0.230522     -0.161930
# StreamingTV                                 0.167188  0.201053     -0.108239
# StreamingMovies                             0.176469  0.205031     -0.114715
# Contract                                   -0.142554  0.671607      0.002247
# PaperlessBilling                            0.156530  0.006152      0.016505
# MonthlyCharges                              0.220173  0.247900      0.247398
# TotalCharges                                0.102652  0.825464      0.113013
# gender_Male                                -0.001874  0.005106     -0.006488
# Partner_Yes                                 0.016479  0.379697      0.017706
# Dependents_Yes                             -0.211185  0.159712     -0.001762
# PaymentMethod_Credit card (automatic)      -0.024135  0.233006     -0.007721
# PaymentMethod_Electronic check              0.171718 -0.208363      0.003062
# PaymentMethod_Mailed check                 -0.153477 -0.233852     -0.003319
#
#                                        MultipleLines  InternetService  \
# SeniorCitizen                               0.113791         0.032310
# tenure                                      0.258958         0.030359
# PhoneService                                0.675070        -0.387436
# MultipleLines                               1.000000        -0.186826
# InternetService                            -0.186826         1.000000
# OnlineSecurity                              0.069085         0.720587
# OnlineBackup                                0.130619         0.650962
# DeviceProtection                            0.124502         0.646159
# TechSupport                                 0.069149         0.716993
# StreamingTV                                 0.165254         0.593193
# StreamingMovies                             0.162841         0.597266
# Contract                                    0.083343        -0.099721
# PaperlessBilling                            0.133255         0.138625
# MonthlyCharges                              0.490700         0.323260
# TotalCharges                                0.412166         0.175589
# gender_Male                                -0.009451         0.000863
# Partner_Yes                                 0.117307        -0.000891
# Dependents_Yes                             -0.019657        -0.044590
# PaymentMethod_Credit card (automatic)       0.042590         0.032540
# PaymentMethod_Electronic check              0.065663         0.091881
# PaymentMethod_Mailed check                 -0.176117        -0.152481
#
#                                        OnlineSecurity  OnlineBackup  \
# SeniorCitizen                                0.081878      0.144828
# tenure                                       0.232373      0.253743
# PhoneService                                -0.159989     -0.129770
# MultipleLines                                0.069085      0.130619
# InternetService                              0.720587      0.650962
# OnlineSecurity                               1.000000      0.705166
# OnlineBackup                                 0.705166      1.000000
# DeviceProtection                             0.701690      0.711335
# TechSupport                                  0.735191      0.709216
# StreamingTV                                  0.662220      0.703167
# StreamingMovies                              0.667033      0.700158
# Contract                                     0.015824     -0.035407
# PaperlessBilling                             0.184993      0.260715
# MonthlyCharges                               0.635534      0.710477
# TotalCharges                                 0.482605      0.537169
# gender_Male                                 -0.014418     -0.012230
# Partner_Yes                                  0.091303      0.090753
# Dependents_Yes                              -0.029721     -0.062775
# PaymentMethod_Credit card (automatic)        0.073520      0.057873
# PaymentMethod_Electronic check               0.094304      0.158719
# PaymentMethod_Mailed check                  -0.239277     -0.291444
#
#                                        DeviceProtection  TechSupport  \
# SeniorCitizen                                  0.140298     0.067457
# tenure                                         0.253999     0.230522
# PhoneService                                  -0.142012    -0.161930
# MultipleLines                                  0.124502     0.069149
# InternetService                                0.646159     0.716993
# OnlineSecurity                                 0.701690     0.735191
# OnlineBackup                                   0.711335     0.709216
# DeviceProtection                               1.000000     0.725327
# TechSupport                                    0.725327     1.000000
# StreamingTV                                    0.748182     0.703866
# StreamingMovies                                0.752952     0.704587
# Contract                                       0.005848     0.047218
# PaperlessBilling                               0.246069     0.211031
# MonthlyCharges                                 0.737104     0.661032
# TotalCharges                                   0.545529     0.495075
# gender_Male                                   -0.004720    -0.009409
# Partner_Yes                                    0.098664     0.076551
# Dependents_Yes                                -0.069078    -0.040788
# PaymentMethod_Credit card (automatic)          0.071243     0.074562
# PaymentMethod_Electronic check                 0.156932     0.092152
# PaymentMethod_Mailed check                    -0.300069    -0.241759
#
#                                        StreamingTV  ...  Contract  \
# SeniorCitizen                             0.167188  ... -0.142554
# tenure                                    0.201053  ...  0.671607
# PhoneService                             -0.108239  ...  0.002247
# MultipleLines                             0.165254  ...  0.083343
# InternetService                           0.593193  ... -0.099721
# OnlineSecurity                            0.662220  ...  0.015824
# OnlineBackup                              0.703167  ... -0.035407
# DeviceProtection                          0.748182  ...  0.005848
# TechSupport                               0.703866  ...  0.047218
# StreamingTV                               1.000000  ... -0.065128
# StreamingMovies                           0.807221  ... -0.062583
# Contract                                 -0.065128  ...  1.000000
# PaperlessBilling                          0.318581  ... -0.176733
# MonthlyCharges                            0.820225  ... -0.074195
# TotalCharges                              0.535105  ...  0.448564
# gender_Male                              -0.008673  ...  0.000126
# Partner_Yes                               0.079785  ...  0.294806
# Dependents_Yes                           -0.086739  ...  0.243187
# PaymentMethod_Credit card (automatic)     0.025425  ...  0.210659
# PaymentMethod_Electronic check            0.248025  ... -0.342575
# PaymentMethod_Mailed check               -0.334131  ... -0.004882
#
#                                        PaperlessBilling  MonthlyCharges  \
# SeniorCitizen                                  0.156530        0.220173
# tenure                                         0.006152        0.247900
# PhoneService                                   0.016505        0.247398
# MultipleLines                                  0.133255        0.490700
# InternetService                                0.138625        0.323260
# OnlineSecurity                                 0.184993        0.635534
# OnlineBackup                                   0.260715        0.710477
# DeviceProtection                               0.246069        0.737104
# TechSupport                                    0.211031        0.661032
# StreamingTV                                    0.318581        0.820225
# StreamingMovies                                0.310385        0.817842
# Contract                                      -0.176733       -0.074195
# PaperlessBilling                               1.000000        0.352150
# MonthlyCharges                                 0.352150        1.000000
# TotalCharges                                   0.158055        0.650865
# gender_Male                                   -0.011754       -0.014569
# Partner_Yes                                   -0.014877        0.096848
# Dependents_Yes                                -0.111377       -0.113890
# PaymentMethod_Credit card (automatic)         -0.013589        0.030550
# PaymentMethod_Electronic check                 0.208865        0.271625
# PaymentMethod_Mailed check                    -0.205398       -0.377437
#
#                                        TotalCharges  gender_Male  Partner_Yes  \
# SeniorCitizen                              0.102652    -0.001874     0.016479
# tenure                                     0.825464     0.005106     0.379697
# PhoneService                               0.113013    -0.006488     0.017706
# MultipleLines                              0.412166    -0.009451     0.117307
# InternetService                            0.175589     0.000863    -0.000891
# OnlineSecurity                             0.482605    -0.014418     0.091303
# OnlineBackup                               0.537169    -0.012230     0.090753
# DeviceProtection                           0.545529    -0.004720     0.098664
# TechSupport                                0.495075    -0.009409     0.076551
# StreamingTV                                0.535105    -0.008673     0.079785
# StreamingMovies                            0.537535    -0.010011     0.075098
# Contract                                   0.448564     0.000126     0.294806
# PaperlessBilling                           0.158055    -0.011754    -0.014877
# MonthlyCharges                             0.650865    -0.014569     0.096848
# TotalCharges                               1.000000    -0.000002     0.318364
# gender_Male                               -0.000002     1.000000    -0.001808
# Partner_Yes                                0.318364    -0.001808     1.000000
# Dependents_Yes                             0.063593     0.010517     0.452676
# PaymentMethod_Credit card (automatic)      0.182745     0.001215     0.082029
# PaymentMethod_Electronic check            -0.059971     0.000752    -0.083852
# PaymentMethod_Mailed check                -0.294815     0.013744    -0.095125
#
#                                        Dependents_Yes  \
# SeniorCitizen                               -0.211185
# tenure                                       0.159712
# PhoneService                                -0.001762
# MultipleLines                               -0.019657
# InternetService                             -0.044590
# OnlineSecurity                              -0.029721
# OnlineBackup                                -0.062775
# DeviceProtection                            -0.069078
# TechSupport                                 -0.040788
# StreamingTV                                 -0.086739
# StreamingMovies                             -0.101475
# Contract                                     0.243187
# PaperlessBilling                            -0.111377
# MonthlyCharges                              -0.113890
# TotalCharges                                 0.063593
# gender_Male                                  0.010517
# Partner_Yes                                  0.452676
# Dependents_Yes                               1.000000
# PaymentMethod_Credit card (automatic)        0.060267
# PaymentMethod_Electronic check              -0.150642
# PaymentMethod_Mailed check                   0.059071
#
#                                        PaymentMethod_Credit card (automatic)  \
# SeniorCitizen                                                      -0.024135
# tenure                                                              0.233006
# PhoneService                                                       -0.007721
# MultipleLines                                                       0.042590
# InternetService                                                     0.032540
# OnlineSecurity                                                      0.073520
# OnlineBackup                                                        0.057873
# DeviceProtection                                                    0.071243
# TechSupport                                                         0.074562
# StreamingTV                                                         0.025425
# StreamingMovies                                                     0.030648
# Contract                                                            0.210659
# PaperlessBilling                                                   -0.013589
# MonthlyCharges                                                      0.030550
# TotalCharges                                                        0.182745
# gender_Male                                                         0.001215
# Partner_Yes                                                         0.082029
# Dependents_Yes                                                      0.060267
# PaymentMethod_Credit card (automatic)                               1.000000
# PaymentMethod_Electronic check                                     -0.373322
# PaymentMethod_Mailed check                                         -0.286049
#
#                                        PaymentMethod_Electronic check  \
# SeniorCitizen                                                0.171718
# tenure                                                      -0.208363
# PhoneService                                                 0.003062
# MultipleLines                                                0.065663
# InternetService                                              0.091881
# OnlineSecurity                                               0.094304
# OnlineBackup                                                 0.158719
# DeviceProtection                                             0.156932
# TechSupport                                                  0.092152
# StreamingTV                                                  0.248025
# StreamingMovies                                              0.243398
# Contract                                                    -0.342575
# PaperlessBilling                                             0.208865
# MonthlyCharges                                               0.271625
# TotalCharges                                                -0.059971
# gender_Male                                                  0.000752
# Partner_Yes                                                 -0.083852
# Dependents_Yes                                              -0.150642
# PaymentMethod_Credit card (automatic)                       -0.373322
# PaymentMethod_Electronic check                               1.000000
# PaymentMethod_Mailed check                                  -0.387372
#
#                                        PaymentMethod_Mailed check
# SeniorCitizen                                           -0.153477
# tenure                                                  -0.233852
# PhoneService                                            -0.003319
# MultipleLines                                           -0.176117
# InternetService                                         -0.152481
# OnlineSecurity                                          -0.239277
# OnlineBackup                                            -0.291444
# DeviceProtection                                        -0.300069
# TechSupport                                             -0.241759
# StreamingTV                                             -0.334131
# StreamingMovies                                         -0.335553
# Contract                                                -0.004882
# PaperlessBilling                                        -0.205398
# MonthlyCharges                                          -0.377437
# TotalCharges                                            -0.294815
# gender_Male                                              0.013744
# Partner_Yes                                             -0.095125
# Dependents_Yes                                           0.059071
# PaymentMethod_Credit card (automatic)                   -0.286049
# PaymentMethod_Electronic check                          -0.387372
# PaymentMethod_Mailed check                               1.000000
#
# [21 rows x 21 columns]

# %%
X = pd.concat([X, y], axis=1)

# %%
X.head()
# Out:
#    SeniorCitizen  tenure  PhoneService  MultipleLines  InternetService  \
# 0              0       1             0              0                2
# 1              0      34             1              1                2
# 2              0       2             1              1                2
# 3              0      45             0              0                2
# 4              0       2             1              1                1
#
#    OnlineSecurity  OnlineBackup  DeviceProtection  TechSupport  StreamingTV  \
# 0               1             2                 1            1            1
# 1               2             1                 2            1            1
# 2               2             2                 1            1            1
# 3               2             1                 2            2            1
# 4               1             1                 1            1            1
#
#    ...  PaperlessBilling  MonthlyCharges  TotalCharges  gender_Male  \
# 0  ...                 1           29.85         29.85            0
# 1  ...                 0           56.95       1889.50            1
# 2  ...                 1           53.85        108.15            1
# 3  ...                 0           42.30       1840.75            1
# 4  ...                 1           70.70        151.65            0
#
#    Partner_Yes  Dependents_Yes  PaymentMethod_Credit card (automatic)  \
# 0            1               0                                      0
# 1            0               0                                      0
# 2            0               0                                      0
# 3            0               0                                      0
# 4            0               0                                      0
#
#    PaymentMethod_Electronic check  PaymentMethod_Mailed check  Churn
# 0                               1                           0      0
# 1                               0                           1      0
# 2                               0                           1      1
# 3                               0                           0      0
# 4                               1                           0      1
#
# [5 rows x 22 columns]

# %%
r=X.corr()

# %%
r['Churn']
# Out:
# SeniorCitizen                            0.150889
# tenure                                  -0.352229
# PhoneService                             0.011942
# MultipleLines                            0.036310
# InternetService                          0.047291
# OnlineSecurity                           0.023309
# OnlineBackup                             0.074205
# DeviceProtection                         0.084654
# TechSupport                              0.027037
# StreamingTV                              0.164673
# StreamingMovies                          0.163220
# Contract                                -0.396713
# PaperlessBilling                         0.191825
# MonthlyCharges                           0.193356
# TotalCharges                            -0.199037
# gender_Male                             -0.008612
# Partner_Yes                             -0.150448
# Dependents_Yes                          -0.164221
# PaymentMethod_Credit card (automatic)   -0.134302
# PaymentMethod_Electronic check           0.301919
# PaymentMethod_Mailed check              -0.091683
# Churn                                    1.000000
# Name: Churn, dtype: float64
